# %%
import pickle

# Load training data from DS1
with open('DS1/train_DS1.pkl', 'rb') as f:
    train_data = pickle.load(f)

# %%
print(f"Loaded DS1 training set with {len(train_data)} samples.")
# Out:
# Loaded DS1 training set with 31637 samples.

# %%
# Load validation data from DS1
with open('DS1/val_DS1.pkl', 'rb') as f:
    val_data = pickle.load(f)
# Load testing data from DS1
with open('DS1/test_DS1.pkl', 'rb') as f:
    test_data = pickle.load(f)

# %%
print(f"DS1 validation dataset length :{len(val_data)}")
print(f"DS1 testing dataset length :{len(test_data)}")
# Out:
# DS1 validation dataset length :1863
# DS1 testing dataset length :3722
